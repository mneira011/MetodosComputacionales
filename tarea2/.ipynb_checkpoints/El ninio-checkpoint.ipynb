# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
= np.loadtxt("RotationCurve_F571-8.txt",delimiter=' ', usecols=(0, 1,2,3,4,5,6), unpack=True)daa
# Out:
#   File "<ipython-input-2-9ca60fc7534c>", line 1
#     = np.loadtxt("RotationCurve_F571-8.txt",delimiter=' ', usecols=(0, 1,2,3,4,5,6), unpack=True)daa
#     ^
# SyntaxError: invalid syntax

# %%
datos = open("soiplaintext.txt")
datos.readline()
c=datos.readlines()
# print(c)
d= np.loadtxt(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-90fd20d0329e> in <module>()
#       4 c=datos.readlines()
#       5 # print(c)
# ----> 6 d= np.loadtxt(c)
#
# /home/mauro/anaconda3/lib/python3.5/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     925                 line_num = i + skiprows + 1
#     926                 raise ValueError("Wrong number of columns at line %d"
# --> 927                                  % line_num)
#     928
#     929             # Convert each value according to its column and store
#
# ValueError: Wrong number of columns at line 142

# %%
d=np.genfromtxt("soiplaintext.txt",dtype=str,delimiter='\t',skip_header=1,skip_footer =1)
print(d[len(d)-1].split())
# Out:
# ['2016', '-19.7', '-19.7', '-4.7', '-22.0', '2.8', '5.8', '4.2', '5.3', '13.5', '-4.3', '-0.7', '2.6']

# %%
mes=[]
temp=[]
cont = 0;
for i in range(len(d)):
    for j in range(12):
        if(j!=0):
            temp.append(i.split()[j])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-7d581ffeeb09> in <module>()
#       5     for j in range(12):
#       6         if(j!=0):
# ----> 7             temp.append(i.split()[j])
#
# AttributeError: 'int' object has no attribute 'split'

# %%
print(len(mes),len(temp))
# Out:
# 0 0

# %%
for i in range(len(temp)):
    mes.append(i)

# %%
plt.figure(figsize=(20,20))
plt.plot(mes[1500:],temp[1500:])
